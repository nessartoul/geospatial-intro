# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
# %matplotlib inline

# %% [markdown]
# ### Importing my libraries data [changing to geo]  and my nashville map

# %%
nash = gpd.read_file('./data/nashville_map.geojson')
ax = nash.plot(figsize = (10,10), color = '#cccccc')
ax.axis('off')
# Out:
# (-87.08182285612493, -86.48832059875873, 35.945865086683014, 36.42758826064042)

# %%
library = pd.read_csv('./data/libraries.csv')
## creating my geometry for library

library['geometry'] = library.apply(lambda x: Point((float(x.longitude), 
                                                         float(x.latitude))), 
                                        axis=1)
library_geo = gpd.GeoDataFrame(library, crs = nash.crs, geometry = library['geometry'])

# %%
projects = pd.read_csv('./data/Metro_Public_Works_Capital_Projects.csv')
projects['geometry'] = projects.apply(lambda x: Point((float(x.Longitude), 
                                                         float(x.Latitude))), 
                                        axis=1)
projects_geo = gpd.GeoDataFrame(projects, crs = nash.crs, geometry = projects['geometry'])
type(projects_geo)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# ###### Here is my geo

# %% [markdown]
# ### Checking the files

# %%
nash.head(1)
# Out:
#   area_sq_mi                     name objectid  \
# 0        198  Urban Services District        0
#
#                                             geometry
# 0  MULTIPOLYGON (((-86.68681 36.28671, -86.68706 ...

# %%
library.head(1)
# Out:
#   notes   latitude  longitude  \
# 0        35.681402 -85.774444
#
#                               location/human_address  \
# 0  {"address": "", "city": "", "state": "TN", "zi...
#
#    :@computed_region_sjpq_96s8  :@computed_region_v3ji_vzam library_name  \
# 0                       1521.0                         2159          NaN
#
#   library_photo_url/url library_photo_url/description phone_number  ...  \
# 0                   NaN                           NaN          NaN  ...
#
#   :@computed_region_gxvr_9jxz :@computed_region_gisn_y5cm  \
# 0                         NaN                         NaN
#
#   :@computed_region_c9xn_skx3 :@computed_region_f73m_vb2k sunday_opening_time  \
# 0                         NaN                         NaN                 NaN
#
#   :@computed_region_cfa7_hbpz friday_opening_time friday_closing_time  \
# 0                         NaN                 NaN                 NaN
#
#   sunday_closing_time                    geometry
# 0                 NaN  POINT (-85.77444 35.68140)
#
# [1 rows x 51 columns]

# %%
projects.head(1)
# Out:
#    CP ID Project Number Project Category         Project Type  \
# 0   2324            NaN          Culvert  Culvert Replacement
#
#                             Project Name        Project Location  \
# 0  7288 Indian Creek Road - Steel Plates  7288 Indian Creek Road
#
#                         Description  \
# 0  Temporary plating of bridge deck
#
#                                        Justification Council District  \
# 0  To repair the jobs identified by county wide c...               35
#
#    Plan Cost  ...  Priority     Phase  PPA Number  x Coordinate  y Coordinate  \
# 0    8226.16  ...    Medium  Complete   257-02015  1.684294e+06  658637.43705
#
#   Latitude  Longitude                                            Map URL  \
# 0  36.1389 -86.962506  <a href='https://mpw.nashville.gov/CapitalProj...
#
#                Mapped Location                    geometry
# 0  (36.13889955, -86.96250643)  POINT (-86.96251 36.13890)
#
# [1 rows x 31 columns]

# %% [markdown]
# ### Checking my crs and changing it

# %%
projects.crs = 'EPSG:4326'
nash.crs = 'EPSG:4326'
library.crs = 'EPSG:4326'

# %% [markdown]
# ### Looking at both plots

# %%
nash.plot(figsize = (6,8))

# %%
center = nash.geometry.centroid[1]
nash_center = [center.y, center.x]

# %%
nash_map = folium.Map(nash_center)
nash_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
library_geo.head(1)
# Out:
#   notes   latitude  longitude  \
# 0        35.681402 -85.774444
#
#                               location/human_address  \
# 0  {"address": "", "city": "", "state": "TN", "zi...
#
#    :@computed_region_sjpq_96s8  :@computed_region_v3ji_vzam library_name  \
# 0                       1521.0                         2159          NaN
#
#   library_photo_url/url library_photo_url/description phone_number  ...  \
# 0                   NaN                           NaN          NaN  ...
#
#   :@computed_region_gxvr_9jxz :@computed_region_gisn_y5cm  \
# 0                         NaN                         NaN
#
#   :@computed_region_c9xn_skx3 :@computed_region_f73m_vb2k sunday_opening_time  \
# 0                         NaN                         NaN                 NaN
#
#   :@computed_region_cfa7_hbpz friday_opening_time friday_closing_time  \
# 0                         NaN                 NaN                 NaN
#
#   sunday_closing_time                    geometry
# 0                 NaN  POINT (-85.77444 35.68140)
#
# [1 rows x 51 columns]

# %%
nash_lib_map = folium.Map(nash_center, tiles = 'Stamen Toner', zoom_start = 12)


for row_index, row_values in library_geo.iterrows():
    loc = [row_values['latitude'], row_values['longitude']]
    pop = str(row_values['library_name']),str(row_values['hoop'])
    marker = folium.Marker(location = loc, popup = pop,icon = folium.Icon(icon = 'book',color = 'lightblue'))
    
    marker.add_to(nash_lib_map)


    
nash_lib_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
nash_lib_map = folium.Map(nash_center, tiles = 'Stamen Toner', zoom_start = 12)

cluster_zip = folium.Map(location = nash_center)
marker_cluster = MarkerCluster(color = 'green').add_to(nash_lib_map)
for row_index, row_values in library_geo.iterrows():
    loc = [row_values['latitude'], row_values['longitude']]
    pop = str(row_values['library_name']),str(row_values['hoop'])
    marker = folium.Marker(location = loc, popup = pop,icon = folium.Icon(icon = 'book',color = 'lightblue'))
    
    marker.add_to(nash_lib_map)

for row_index, row_values in projects_geo.iterrows():
    loc = [row_values['Latitude'], row_values['Longitude']]
    pop = str(row_values['Project Type'])
    marker = folium.Marker(location = loc, popup = pop, icon = folium.Icon(icon='tool'))
    
    marker.add_to(marker_cluster)
    
nash_lib_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
